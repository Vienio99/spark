# %% [markdown]
# Spark Ćwiczenia

# %%
from pyspark.sql import SparkSession

# %%
import pandas as pd

# %%
import numpy as np

# %%
spark = SparkSession.builder.getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://38203a85c171:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
airports = spark.read.csv("airports.csv",inferSchema=True,header=True)

# %%
airports.toPandas()
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# 3                          Aberdeen    SD     USA  45.44906  -98.42183
# 4                            Albany    GA     USA  31.53552  -84.19447
# ..                              ...   ...     ...       ...        ...
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597
#
# [322 rows x 7 columns]

# %%
from pyspark.sql.functions import col, asc

# %% [markdown]
# Zadania

# %% [markdown]
# nr1 Print all the airports that are to the North from Krakow.

# %%
airports.filter(col("LATITUDE") > 50).toPandas()
# Out:
#    IATA_CODE                                      AIRPORT         CITY STATE  \
# 0        ADK                                 Adak Airport         Adak    AK
# 1        ADQ                               Kodiak Airport       Kodiak    AK
# 2        AKN                          King Salmon Airport  King Salmon    AK
# 3        ANC  Ted Stevens Anchorage International Airport    Anchorage    AK
# 4        BET                               Bethel Airport       Bethel    AK
# 5        BRW      Wiley Post-Will Rogers Memorial Airport       Barrow    AK
# 6        CDV             Merle K. (Mudhole) Smith Airport      Cordova    AK
# 7        DLG                           Dillingham Airport   Dillingham    AK
# 8        FAI              Fairbanks International Airport    Fairbanks    AK
# 9        GST                             Gustavus Airport     Gustavus    AK
# 10       JNU                 Juneau International Airport       Juneau    AK
# 11       KTN              Ketchikan International Airport    Ketchikan    AK
# 12       OME                                 Nome Airport         Nome    AK
# 13       OTZ                  Ralph Wien Memorial Airport     Kotzebue    AK
# 14       PSG          Petersburg James A. Johnson Airport   Petersburg    AK
# 15       SCC      Deadhorse Airport (Prudhoe Bay Airport)    Deadhorse    AK
# 16       SIT                Sitka Rocky Gutierrez Airport        Sitka    AK
# 17       WRG                             Wrangell Airport     Wrangell    AK
# 18       YAK                              Yakutat Airport      Yakutat    AK
#
#    COUNTRY  LATITUDE  LONGITUDE
# 0      USA  51.87796 -176.64603
# 1      USA  57.74997 -152.49386
# 2      USA  58.67680 -156.64922
# 3      USA  61.17432 -149.99619
# 4      USA  60.77978 -161.83800
# 5      USA  71.28545 -156.76600
# 6      USA  60.49183 -145.47765
# 7      USA  59.04541 -158.50334
# 8      USA  64.81368 -147.85967
# 9      USA  58.42438 -135.70738
# 10     USA  58.35496 -134.57628
# 11     USA  55.35557 -131.71374
# 12     USA  64.51220 -165.44525
# 13     USA  66.88468 -162.59855
# 14     USA  56.80165 -132.94528
# 15     USA  70.19476 -148.46516
# 16     USA  57.04714 -135.36160
# 17     USA  56.48433 -132.36982
# 18     USA  59.50336 -139.66023

# %% [markdown]
# nr2 For each state, find the airport which is closest to the South Pole.

# %%
import matplotlib

# %%
pd_airports = airports.select("longitude", "latitude").toPandas()

# %%
pd_airports
# Out:
#      longitude  latitude
# 0    -75.44040  40.65236
# 1    -99.68190  32.41132
# 2   -106.60919  35.04022
# 3    -98.42183  45.44906
# 4    -84.19447  31.53552
# ..         ...       ...
# 317 -132.36982  56.48433
# 318 -111.11764  44.68840
# 319  -94.30681  36.28187
# 320 -139.66023  59.50336
# 321 -114.60597  32.65658
#
# [322 rows x 2 columns]

# %% [markdown]
# nr3 Plot the coordinates of all the airports. Bonus: plot on the map.

# %%
pd_airports.plot(x="longitude", y="latitude", kind="scatter",figsize=(10, 6))

# %%
countries = spark.read.csv("countries of the world.csv",inferSchema=True,header=True)

# %%
countries.toPandas()
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0            647500                       48,0                         0,00
# 1             28748                      124,6                         1,26
# 2           2381740                       13,8                         0,04
# 3               199                      290,4                        58,29
# 4               468                      152,1                         0,00
# ..              ...                        ...                          ...
# 222            5860                      419,9                         0,00
# 223          266000                        1,0                         0,42
# 224          527970                       40,6                         0,36
# 225          752614                       15,3                         0,00
# 226          390580                       31,3                         0,00
#
#     Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0           23,06                             163,07               700.0
# 1           -4,93                              21,52              4500.0
# 2           -0,39                                 31              6000.0
# 3          -20,71                               9,27              8000.0
# 4             6,6                               4,05             19000.0
# ..            ...                                ...                 ...
# 222          2,98                              19,62               800.0
# 223          None                               None                 NaN
# 224             0                               61,5               800.0
# 225             0                              88,29               800.0
# 226             0                              67,69              1900.0
#
#     Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0           36,0               3,2      12,13      0,22     87,65       1
# 1           86,5              71,2      21,09      4,42     74,49       3
# 2           70,0              78,1       3,22      0,25     96,53       1
# 3           97,0             259,5         10        15        75       2
# 4          100,0             497,2       2,22         0     97,78       3
# ..           ...               ...        ...       ...       ...     ...
# 222         None             145,2       16,9     18,97     64,13       3
# 223         None              None       0,02         0     99,98       1
# 224         50,2              37,2       2,78      0,24     96,98       1
# 225         80,6               8,2       7,08      0,03      92,9       2
# 226         90,7              26,8       8,32      0,34     91,34       2
#
#     Birthrate Deathrate Agriculture Industry Service
# 0        46,6     20,34        0,38     0,24    0,38
# 1       15,11      5,22       0,232    0,188   0,579
# 2       17,14      4,61       0,101      0,6   0,298
# 3       22,46      3,27        None     None    None
# 4        8,71      6,25        None     None    None
# ..        ...       ...         ...      ...     ...
# 222     31,67      3,92        0,09     0,28    0,63
# 223      None      None        None     None     0,4
# 224     42,89       8,3       0,135    0,472   0,393
# 225        41     19,93        0,22     0,29   0,489
# 226     28,01     21,84       0,179    0,243   0,579
#
# [227 rows x 20 columns]

# %% [markdown]
# nr4 Plot GDP vs. Phones for all countries in Asia.

# %%
from pyspark.sql.types import FloatType
from pyspark.sql.functions import udf

# %%
def to_float (s) :
   return float(s.replace(',','.'))

# %%
float_udf = udf(to_float , FloatType())

# %%
full_countries = countries.select("Region",'GDP ($ per capita)',"Phones (per 1000)" ).na.drop()

# %%
full_countries = full_countries.withColumn("Phones", float_udf("Phones (per 1000)"))

# %%
full_countries.show()
# Out:
# +--------------------+------------------+-----------------+------+
# |              Region|GDP ($ per capita)|Phones (per 1000)|Phones|
# +--------------------+------------------+-----------------+------+
# |ASIA (EX. NEAR EA...|               700|              3,2|   3.2|
# |EASTERN EUROPE   ...|              4500|             71,2|  71.2|
# |NORTHERN AFRICA  ...|              6000|             78,1|  78.1|
# |OCEANIA          ...|              8000|            259,5| 259.5|
# |WESTERN EUROPE   ...|             19000|            497,2| 497.2|
# |SUB-SAHARAN AFRIC...|              1900|              7,8|   7.8|
# |LATIN AMER. & CAR...|              8600|            460,0| 460.0|
# |LATIN AMER. & CAR...|             11000|            549,9| 549.9|
# |LATIN AMER. & CAR...|             11200|            220,4| 220.4|
# |C.W. OF IND. STATES |              3500|            195,7| 195.7|
# |LATIN AMER. & CAR...|             28000|            516,1| 516.1|
# |OCEANIA          ...|             29000|            565,5| 565.5|
# |WESTERN EUROPE   ...|             30000|            452,2| 452.2|
# |C.W. OF IND. STATES |              3400|            137,1| 137.1|
# |LATIN AMER. & CAR...|             16700|            460,6| 460.6|
# |NEAR EAST        ...|             16900|            281,3| 281.3|
# |ASIA (EX. NEAR EA...|              1900|              7,3|   7.3|
# |LATIN AMER. & CAR...|             15700|            481,9| 481.9|
# |C.W. OF IND. STATES |              6100|            319,1| 319.1|
# |WESTERN EUROPE   ...|             29100|            462,6| 462.6|
# +--------------------+------------------+-----------------+------+
# only showing top 20 rows

# %%
pd_asia = full_countries.select("GDP ($ per capita)", "Phones")\
.where(col("Region").like("%ASIA%")).toPandas()

# %%
pd_asia
# Out:
#     GDP ($ per capita)      Phones
# 0                  700    3.200000
# 1                 1900    7.300000
# 2                 1300   14.300000
# 3                18600  237.199997
# 4                 1800   10.100000
# 5                 1900    2.600000
# 6                 5000  266.700012
# 7                28800  546.700012
# 8                 2900   45.400002
# 9                 3200   52.000000
# 10                7000  276.399994
# 11               28200  461.200012
# 12                1300   42.400002
# 13               17800  486.100006
# 14                1700   14.100000
# 15               19400  384.899994
# 16                9000  179.000000
# 17                3900   90.000000
# 18                1800   55.099998
# 19                1400   15.900000
# 20                2100   31.799999
# 21                4600   38.400002
# 22               23700  411.399994
# 23                3700   61.500000
# 24               23400  591.000000
# 25                7400  108.900002
# 26                2500  187.699997

# %%
pd_asia.plot(x="GDP ($ per capita)", y="Phones", kind="scatter",figsize=(10, 6))

# %% [markdown]
# nr5 Plot Infant mortality vs. Literacy for top 30 richest and top 30 poorest countries.
